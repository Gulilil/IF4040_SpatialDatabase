# %%
import geopandas as gpd
import psycopg2
import matplotlib.pyplot as plt
import pandas as pd 
import numpy as np
from dotenv import load_dotenv
import os 
load_dotenv()
# Out:
# True

# %%
conn = psycopg2.connect(user=os.getenv("POSTGRE_DB_USER"), 
                        database=os.getenv("POSTGRE_DB_NAME"),
                        password=os.getenv("POSTGRE_DB_PASSWORD"),
                        host=os.getenv("POSTGRE_DB_HOST"),
                        port=os.getenv("POSTGRE_DB_PORT"))
query = "SELECT shape FROM country"
gdf = gpd.read_postgis(query, conn, geom_col='shape')

gdf.plot()
plt.show()

conn.close()
# Out:
# c:\Users\Juan Christopher\AppData\Local\Programs\Python\Python311\Lib\site-packages\geopandas\io\sql.py:185: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(
# c:\Users\Juan Christopher\AppData\Local\Programs\Python\Python311\Lib\site-packages\geopandas\io\sql.py:473: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   return pd.read_sql(spatial_ref_sys_sql, con)

# %%
conn = psycopg2.connect(user=os.getenv("POSTGRE_DB_USER"), 
                        database=os.getenv("POSTGRE_DB_NAME"),
                        password=os.getenv("POSTGRE_DB_PASSWORD"),
                        host=os.getenv("POSTGRE_DB_HOST"),
                        port=os.getenv("POSTGRE_DB_PORT"))
query = "SELECT shape FROM region"
gdf = gpd.read_postgis(query, conn, geom_col='shape')

gdf.plot()
plt.show()

conn.close()
# Out:
# c:\Users\Juan Christopher\AppData\Local\Programs\Python\Python311\Lib\site-packages\geopandas\io\sql.py:185: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(
# c:\Users\Juan Christopher\AppData\Local\Programs\Python\Python311\Lib\site-packages\geopandas\io\sql.py:473: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   return pd.read_sql(spatial_ref_sys_sql, con)

# %%
conn = psycopg2.connect(user=os.getenv("POSTGRE_DB_USER"), 
                        database=os.getenv("POSTGRE_DB_NAME"),
                        password=os.getenv("POSTGRE_DB_PASSWORD"),
                        host=os.getenv("POSTGRE_DB_HOST"),
                        port=os.getenv("POSTGRE_DB_PORT"))

query = "SELECT shape FROM district"
gdf = gpd.read_postgis(query, conn, geom_col='shape')

gdf.plot()
plt.show()

conn.close()
# Out:
# c:\Users\Juan Christopher\AppData\Local\Programs\Python\Python311\Lib\site-packages\geopandas\io\sql.py:185: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(
# c:\Users\Juan Christopher\AppData\Local\Programs\Python\Python311\Lib\site-packages\geopandas\io\sql.py:473: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   return pd.read_sql(spatial_ref_sys_sql, con)

# %%
conn = psycopg2.connect(user=os.getenv("POSTGRE_DB_USER"), 
                        database=os.getenv("POSTGRE_DB_NAME"),
                        password=os.getenv("POSTGRE_DB_PASSWORD"),
                        host=os.getenv("POSTGRE_DB_HOST"),
                        port=os.getenv("POSTGRE_DB_PORT"))

query = "SELECT line FROM road"
gdf = gpd.read_postgis(query, conn, geom_col='line')

gdf.plot()
plt.show()

conn.close()
# Out:
# c:\Users\Juan Christopher\AppData\Local\Programs\Python\Python311\Lib\site-packages\geopandas\io\sql.py:185: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(
# c:\Users\Juan Christopher\AppData\Local\Programs\Python\Python311\Lib\site-packages\geopandas\io\sql.py:473: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   return pd.read_sql(spatial_ref_sys_sql, con)

# %%
conn = psycopg2.connect(user=os.getenv("POSTGRE_DB_USER"), 
                        database=os.getenv("POSTGRE_DB_NAME"),
                        password=os.getenv("POSTGRE_DB_PASSWORD"),
                        host=os.getenv("POSTGRE_DB_HOST"),
                        port=os.getenv("POSTGRE_DB_PORT"))

query = "SELECT line FROM rail"
gdf = gpd.read_postgis(query, conn, geom_col='line')

gdf.plot()
plt.show()

conn.close()
# Out:
# c:\Users\Juan Christopher\AppData\Local\Programs\Python\Python311\Lib\site-packages\geopandas\io\sql.py:185: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(
# c:\Users\Juan Christopher\AppData\Local\Programs\Python\Python311\Lib\site-packages\geopandas\io\sql.py:473: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   return pd.read_sql(spatial_ref_sys_sql, con)

# %%
conn = psycopg2.connect(user=os.getenv("POSTGRE_DB_USER"), 
                        database=os.getenv("POSTGRE_DB_NAME"),
                        password=os.getenv("POSTGRE_DB_PASSWORD"),
                        host=os.getenv("POSTGRE_DB_HOST"),
                        port=os.getenv("POSTGRE_DB_PORT"))

query = "SELECT point FROM earthquake"
gdf = gpd.read_postgis(query, conn, geom_col='point')

gdf.plot()
plt.show()

conn.close()
# Out:
# c:\Users\Juan Christopher\AppData\Local\Programs\Python\Python311\Lib\site-packages\geopandas\io\sql.py:185: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(
# c:\Users\Juan Christopher\AppData\Local\Programs\Python\Python311\Lib\site-packages\geopandas\io\sql.py:473: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   return pd.read_sql(spatial_ref_sys_sql, con)
